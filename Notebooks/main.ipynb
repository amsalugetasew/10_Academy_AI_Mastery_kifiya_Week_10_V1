# %% [markdown]
# ## Imporing Important Packages

# %%
# %load_ext autoreload
# %autoreload 2
import sys
import os
# Add Scripts folder to Python path
sys.path.append(os.path.abspath("../Scripts"))
# Import DataLoader class
from data_load import DataLoader
from preprocessing import Preprocessing
from model_building import BrentOilAnalysis
from plot import Plot
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Initialize Classes

# %%
# Initialize DataLoader
loader = DataLoader()

# %% [markdown]
# ## Loading Data

# %%
# Load data
df = loader.load_csv("BrentOilPrices.csv")  # Replace with your file name

# %% [markdown]
# ## Previewing Sample Data

# %%
# Display Data
df
# Out:
#               Date  Price
# 0        20-May-87  18.63
# 1        21-May-87  18.45
# 2        22-May-87  18.55
# 3        25-May-87  18.60
# 4        26-May-87  18.63
# ...            ...    ...
# 9006  Nov 08, 2022  96.85
# 9007  Nov 09, 2022  93.05
# 9008  Nov 10, 2022  94.25
# 9009  Nov 11, 2022  96.37
# 9010  Nov 14, 2022  93.59
#
# [9011 rows x 2 columns]

# %% [markdown]
# ## Data Preprocessing

# %%
preprocessing = Preprocessing(df)

# %%
# preprocessing.Date_Transaformation()

# %% [markdown]
# ## Handling Missing Values

# %%
preprocessing.Handling_missing_values()
# Out:
# Handling Missing Value is completed.

# %% [markdown]
# ## Handling Duplicate Values

# %%
preprocessing.Handling_duplicate_values()
# Out:
# Handling Duplicate Value is completed.
# Data preprocessing completed.
#               Date  Price
# 0        01-Apr-02  26.06
# 1        01-Apr-03  27.94
# 2        01-Apr-04  32.59
# 3        01-Apr-05  54.14
# 4        01-Apr-08  98.69
# ...            ...    ...
# 9006  Sep 29, 2021  77.86
# 9007  Sep 29, 2022  89.41
# 9008  Sep 30, 2020  40.30
# 9009  Sep 30, 2021  77.81
# 9010  Sep 30, 2022  88.90
#
# [9011 rows x 2 columns]

# %% [markdown]
# ## EDA

# %%
plot = Plot(df)

# %%
plot.time_series_analysis()
# Out:
# c:\Users\Admin\10_Academy_AI_Mastery_kifiya_Week_10_V1\Scripts\plot.py:13: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   plt.plot(self.data['Date'], self.data['Price'], label='Brent Oil Price')
# c:\Users\Admin\10_Academy_AI_Mastery_kifiya_Week_10_V1\Scripts\plot.py:16: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   plt.title('Brent Oil Prices Over Time')

# %%
plot.plot_decomposition_results()

# %%
plot.Augmented_Dickey_Fuller_test()
# Out:
# ADF Statistic: -1.993856011392466
# p-value: 0.2892735048934034
# The time series is non-stationary. Differencing is required.

# %%
# preprocessing = Preprocessing(df)

# %%
# df = preprocessing.preprocess_data()

# %%
df
# Out:
#               Date  Price
# 0        20-May-87  18.63
# 1        21-May-87  18.45
# 2        22-May-87  18.55
# 3        25-May-87  18.60
# 4        26-May-87  18.63
# ...            ...    ...
# 9006  Nov 08, 2022  96.85
# 9007  Nov 09, 2022  93.05
# 9008  Nov 10, 2022  94.25
# 9009  Nov 11, 2022  96.37
# 9010  Nov 14, 2022  93.59
#
# [9011 rows x 2 columns]

# %%
# brent_analysis = BrentOilAnalysis(df)

# %%
# brent_analysis.build_arima_model()

# %%
# brent_analysis.save_model('arima_model.pkl')

# %%
# For LSTM model:
# brent_analysis.build_lstm_model()

# %%
# brent_analysis.save_model('lstm_model.h5')

# %%
analysis = BrentOilAnalysis(df)

# %%
analysis.preprocess_data()
# Out:
# Data Preprocessed Successfully
# c:\Users\Admin\10_Academy_AI_Mastery_kifiya_Week_10_V1\Scripts\model_building.py:21: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   self.data.fillna(method='ffill', inplace=True)

# %%
analysis.exploratory_data_analysis()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 analysis.exploratory_data_analysis()
#
# File c:\Users\Admin\10_Academy_AI_Mastery_kifiya_Week_10_V1\Scripts\model_building.py:35, in BrentOilAnalysis.exploratory_data_analysis(self)
#      32 plt.legend()
#      33 plt.show()
# ---> 35 sns.heatmap(self.data.corr(), annot=True, cmap='coolwarm')
#      36 plt.show()
#      37 print("EDA Completed Successfully")
#
# File c:\Users\Admin\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# ...

# %%
analysis.build_arima_model()
# Out:
# c:\Users\Admin\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency ns will be used.
#   self._init_dates(dates, freq)
# c:\Users\Admin\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency ns will be used.
#   self._init_dates(dates, freq)
# c:\Users\Admin\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency ns will be used.
#   self._init_dates(dates, freq)
# ARIMA Model Built Successfully
#                                SARIMAX Results
# ...
# Dep. Variable:                  Price   No. Observations:                 9011
# Model:                 ARIMA(5, 1, 0)   Log Likelihood              -14540.613
# ...

# %%
# analysis.build_var_model(5)

# %%
analysis.build_lstm_model()
# Out:
# c:\Users\Admin\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/10
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - loss: 0.0060
# Epoch 2/10
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - loss: 3.7053e-04
# Epoch 3/10
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - loss: 3.4120e-04
# Epoch 4/10
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - loss: 2.8463e-04
# Epoch 5/10
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 2.1929e-04
# Epoch 6/10
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 2.0154e-04
# Epoch 7/10
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 1.5988e-04
# Epoch 8/10
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 1.4985e-04
# Epoch 9/10
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - loss: 1.2513e-04
# ...

# %%
analysis.save_model('lstm_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# LSTM Model Saved Successfully

# %%
forecast = analysis.predict()
print("Forecast:", round(forecast[0][0]*10, 2))
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Forecast Generated Successfully
# Forecast: 6.3
# c:\Users\Admin\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\keras\src\trainers\epoch_iterator.py:107: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
